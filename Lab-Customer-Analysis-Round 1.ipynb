# %%
import pandas as pd

# %%
df1 = pd.read_csv('/Users/vihaan/Desktop/Ironhack/Unit1/Day3/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')

# %%
df2 = pd.read_csv('/Users/vihaan/Desktop/Ironhack/Unit1/Day3/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')

# %%
df3 = pd.read_csv('/Users/vihaan/Desktop/Ironhack/Unit1/Day3/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
len(df1.columns)
# Out:
# 11

# %%
len(df2.columns)
# Out:
# 11

# %%
len(df3.columns)
# Out:
# 11

# %%
df1 = df1.rename(columns = {"ST" : "State",
                     "GENDER" : "Gender"})

# %%
df2 = df2.rename(columns = {"ST" : "State",
                     "GENDER" : "Gender"})

# %%
df1.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
df1 = df1[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]
df1.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df2 = df2[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]
df2.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df3 = df3[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]
df3.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
python = pd.concat([df1, df2, df3])
python
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
python.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
python.columns = [column.lower().replace(' ', '_') for column in python.columns]

# %%
python.select_dtypes("number").columns
# Out:
# Index(['income', 'monthly_premium_auto', 'total_claim_amount'], dtype='object')

# %%
python_categorical = python.select_dtypes("object").columns
python_categorical
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'number_of_open_complaints', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
python_numerical = python.select_dtypes("number").columns
python_numerical
# Out:
# Index(['income', 'monthly_premium_auto', 'total_claim_amount'], dtype='object')

# %%
python.isna().sum()
# Out:
# customer                     2937
# state                        2937
# gender                       3059
# education                    2937
# customer_lifetime_value      2944
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints    2937
# policy_type                  2937
# vehicle_class                2937
# total_claim_amount           2937
# dtype: int64

# %%
python.drop(['education', 'number_of_open_complaints'], axis = 1)
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
python = python.dropna(subset=['customer_lifetime_value'])
python
# Out:
#      customer       state gender             education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# ...

# %%
python.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
def my_function(string):
    return float(str(string).replace("%",""))*100

# %%
python['customer_lifetime_value'] = python['customer_lifetime_value'].apply(my_function)
# Out:
# /var/folders/13/9ymrqm694sz5_g2ct_qmw0gm0000gn/T/ipykernel_364/1927081889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   python['customer_lifetime_value'] = python['customer_lifetime_value'].apply(my_function)

# %%
python
# Out:
#      customer       state gender             education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 1                6.979536e+07      0.0                  94.0
# 2                1.288743e+08  48767.0                 108.0
# 3                7.645862e+07      0.0                 106.0
# ...

# %%
python1 = python[python['income'] >= 0.4]
python1
# Out:
#      customer       state gender             education  \
# 2     AI49188      Nevada      F              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# 6     XZ87318      Oregon      F               College
# 8     DY87989      Oregon      M              Bachelor
# ...       ...         ...    ...                   ...
# 7063  TF56202  California      M               College
# 7064  YM19146  California      F               College
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7068  UP19263  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 2                1.288743e+08  48767.0                 108.0
# 4                5.363076e+07  36357.0                  68.0
# 5                8.256298e+07  62902.0                  69.0
# ...

# %%
python1.drop_duplicates()
# Out:
#      customer       state gender             education  \
# 2     AI49188      Nevada      F              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# 6     XZ87318      Oregon      F               College
# 8     DY87989      Oregon      M              Bachelor
# ...       ...         ...    ...                   ...
# 7063  TF56202  California      M               College
# 7064  YM19146  California      F               College
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7068  UP19263  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 2                1.288743e+08  48767.0                 108.0
# 4                5.363076e+07  36357.0                  68.0
# 5                8.256298e+07  62902.0                  69.0
# ...
